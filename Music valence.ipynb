# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('./data.csv')
df.head()
# Out:
#    Key  acousticness  danceability  duration_ms  energy  instrumentalness  \
# 0    0        0.0102         0.833       204600   0.434          0.021900
# 1    1        0.1990         0.743       326933   0.359          0.006110
# 2    2        0.0344         0.838       185707   0.412          0.000234
# 3    3        0.6040         0.494       199413   0.338          0.510000
# 4    4        0.1800         0.678       392893   0.561          0.512000
#
#    key  liveness  loudness  mode  speechiness    tempo  time_signature  \
# 0    2    0.1650    -8.795     1       0.4310  150.062               4
# 1    1    0.1370   -10.401     1       0.0794  160.083               4
# 2    2    0.1590    -7.148     1       0.2890   75.044               4
# 3    5    0.0922   -15.236     1       0.0261   86.468               4
# 4    5    0.4390   -11.648     0       0.0694  174.004               4
#
#    valence  target      song_title            artist
# ...

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
m=pd.read_csv('data.csv')

# %%
m.head()
# Out:
#    Key  acousticness  danceability  duration_ms  energy  instrumentalness  \
# 0    0        0.0102         0.833       204600   0.434          0.021900
# 1    1        0.1990         0.743       326933   0.359          0.006110
# 2    2        0.0344         0.838       185707   0.412          0.000234
# 3    3        0.6040         0.494       199413   0.338          0.510000
# 4    4        0.1800         0.678       392893   0.561          0.512000
#
#    key  liveness  loudness  mode  speechiness    tempo  time_signature  \
# 0    2    0.1650    -8.795     1       0.4310  150.062               4
# 1    1    0.1370   -10.401     1       0.0794  160.083               4
# 2    2    0.1590    -7.148     1       0.2890   75.044               4
# 3    5    0.0922   -15.236     1       0.0261   86.468               4
# 4    5    0.4390   -11.648     0       0.0694  174.004               4
#
#    valence  target      song_title            artist
# ...

# %%
m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2017 entries, 0 to 2016
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Key               2017 non-null   int64
#  1   acousticness      2017 non-null   float64
#  2   danceability      2017 non-null   float64
#  3   duration_ms       2017 non-null   int64
#  4   energy            2017 non-null   float64
#  5   instrumentalness  2017 non-null   float64
#  6   key               2017 non-null   int64
#  7   liveness          2017 non-null   float64
#  8   loudness          2017 non-null   float64
#  9   mode              2017 non-null   int64
#  10  speechiness       2017 non-null   float64
#  11  tempo             2017 non-null   float64
#  12  time_signature    2017 non-null   int64
#  13  valence           2017 non-null   float64
#  14  target            2017 non-null   int64
#  15  song_title        2017 non-null   object
# ...

# %%
#analyze the correlation between speechiness and valence 
sns.jointplot(m['speechiness'],m['valence'])
# Out:
# c:\users\haven\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#analyze the correlation between speechiness and danceability  
sns.jointplot(m['speechiness'],m['danceability'])
# Out:
# c:\users\haven\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#analyze the proportion of valence by artist 
for col in ['artist']:
    print('**Proportion of valence by Artist**')
    print(m[col].value_counts(normalize=True))
# Out:
# **Proportion of valence by Artist**
# Drake                  0.007933
# Rick Ross              0.006445
# Disclosure             0.005949
# Backstreet Boys        0.004958
# WALK THE MOON          0.004958
#                          ...
# Ejeca                  0.000496
# Raffi                  0.000496
# Wale                   0.000496
# Minor Victories        0.000496
# Panic! At The Disco    0.000496
# Name: artist, Length: 1343, dtype: float64

# %%
#analyze the correlation between danceability and valence
sns.jointplot(m['danceability'],m['valence'])
# Out:
# c:\users\haven\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
